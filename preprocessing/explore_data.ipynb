# %% [markdown]
# # 查看shape

# %%
from monai.data.image_reader import nib

# 读取nii数据
img = nib.load("F:/DATASET/nnUNet_raw/Cropped_Dataset220_KiTS2019/imagesTr_cropped/train/case_00002_0000.nii.gz")
img = img.get_fdata()
# 展示标签
label = nib.load("F:/DATASET/nnUNet_raw/Cropped_Dataset220_KiTS2019/labelsTr_cropped/train/case_00002.nii.gz")
label = label.get_fdata()
# 查看shape
img.shape
# Out:
# (261, 220, 372)

# %%
# 展示数据
import matplotlib.pyplot as plt

plt.imshow(img[150, :, :], cmap='gray')
plt.show()


plt.imshow(label[150, :, :], cmap='gray')
plt.show()
